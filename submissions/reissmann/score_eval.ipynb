# %% [markdown]
# # Submission eval.
# - Name: Maximilian Reissmann & Yuan Fang
# - Method: Differential-evolution for fitting k-omega SST coefficients + Symbolic regression - [GEP](https://github.com/maxreiss123/GeneExpressionProgramming.jl) for anisotropic stress correction
# - Result: One model (anisotropic stress correction) and a new set of k-omega-coeffs.
#
# ## Remarks:
# Loss-formulation: 8 training cases in three stages:
#   - FlatPlate
#   - SubsonicJet
#   - High-Re Channel (LogLaw-loss)
#   - Periodic Hill 10595
#   - AR_1_Ret_180
#   - AR_3_Ret_180
#   - AR_5_Ret_180
#   - AR_10_Ret_180
#
# Method for Point Extraction/ Interpolation: ParaView-filter "Resample with DataSet" (v. 5.10.0-RC1)
#
# For further information:
# reissmannm@student.unimelb.edu.au

# %%
from closure_challenge import score_from_csv
final_score = score_from_csv({
    "alpha_15_13929_4048": "alpha_15_13929_4048/predictions.csv",
    "alpha_15_13929_2024": "alpha_15_13929_2024/predictions.csv",
    "alpha_05_4071_4048": "alpha_05_4071_4048/predictions.csv",
    "alpha_05_4071_2024": "alpha_05_4071_2024/predictions.csv",
    "AR_1_Ret_360": "AR_1_Ret_360/predictions.csv",
    "AR_3_Ret_360": "AR_3_Ret_360/predictions.csv",
    "AR_14_Ret_180": "AR_14_Ret_180/predictions.csv",
    "NASA_2DWMH": "NASA_2DWMH/predictions.csv"
})

# %%
final_score
# Out:
# 0.512347174924715
